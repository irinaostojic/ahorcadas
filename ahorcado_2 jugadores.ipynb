# %%
import random

# Lista de palabras
palabras = [
    'lógica', 'proactividad', 'creatividad',
    'resiliencia', 'comunicación', 'python',
    'programación', 'datos'
]

# Elegir palabra al azar
palabra = random.choice(palabras)

print("¡¡¡BIENVENIDOS AL JUEGO DEL AHORCADO PARA 2 JUGADORES!!!")
# Solo para pruebas, puedes quitarlo después
print(f"(Pista: la palabra es '{palabra}')")
print(f"La palabra contiene {len(palabra)} letras: {'_ ' * len(palabra)}")

# Etapas del ahorcado
ahorcado = [
    """
     ------
     |    |
     |
     |
     |
    _|_
    """,
    """
     ------
     |    |
     |    O
     |
     |
    _|_
    """,
    """
     ------
     |    |
     |    O
     |    |
     |
    _|_
    """,
    """
     ------
     |    |
     |    O
     |   /|
     |
    _|_
    """,
    """
     ------
     |    |
     |    O
     |   /|\\
     |
    _|_
    """,
    """
     ------
     |    |
     |    O
     |   /|\\
     |   /
    _|_
    """,
    """
     ------
     |    |
     |    O
     |   /|\\
     |   / \\
    _|_
    """
]

# Variables del juego
letras_correctas = set()
letras_incorrectas = set()
letras_usadas = set()
intentos = len(ahorcado) - 1
fallos = 0

# Configuración de jugadores
jugadores = ["Jugador 1", "Jugador 2"]
turno = 0  # empieza el Jugador 1

print(f"Tienen {intentos} intentos entre los dos para adivinar la palabra.\n")

# Bucle principal
while True:
    print(ahorcado[fallos])

    # Mostrar estado actual de la palabra
    for letra in palabra:
        if letra.lower() in letras_correctas:
            print(letra, end=" ")
        else:
            print("_", end=" ")
    

    # Mostrar información del turno
    jugador_actual = jugadores[turno] #Nuevo
    print(f"Turno de {jugador_actual}") #Nuevo
    print(f"Letras usadas: {', '.join(sorted(letras_usadas)) if letras_usadas else 'Ninguna'}") #Nuevo

    # Pedir letra
    letra = input("Introduce una letra: ").strip().lower()

    # Validar entrada
    if len(letra) != 1 or not letra.isalpha():
        print("⚠️ Entrada inválida. Introduce una sola letra.")
        continue

    if letra in letras_usadas:
        print("⚠️ Esa letra ya fue usada. Elige otra.")
        continue

    letras_usadas.add(letra)

    # Comprobar si está en la palabra
    if letra in palabra:
        letras_correctas.add(letra)
        print(f"✅ ¡Bien {jugador_actual}! La letra '{letra}' está en la palabra.")
    else:
        letras_incorrectas.add(letra)
        fallos += 1
        print(f"La letra '{letra}' no está en la palabra")
        print(f"Te quedan {(len(ahorcado)-1 - fallos)} intentos")
        print(f"❌Letras incorrectas: {', '.join(sorted(letras_incorrectas))}")
        

    # Comprobar victoria
    if letras_correctas == set(palabra):
        print(f"\n🎉 ¡FELICIDADES {jugador_actual}! Has adivinado la palabra: {palabra}")
        break

    # Comprobar derrota
    if fallos == intentos:
        print(f"\n💀 ¡GAME OVER! La palabra era: {palabra}")
        print(ahorcado[fallos])
        break

    # Cambiar turno
    turno = 1 - turno
# Out:
# ¡¡¡BIENVENIDOS AL JUEGO DEL AHORCADO PARA 2 JUGADORES!!!
# (Pista: la palabra es 'proactividad')
# La palabra contiene 12 letras: _ _ _ _ _ _ _ _ _ _ _ _
# Tienen 6 intentos entre los dos para adivinar la palabra.
#
#
#      ------
#      |    |
#      |
#      |
#      |
#     _|_
#
# _ _ _ _ _ _ _ _ _ _ _ _ Turno de Jugador 1
# Letras usadas: Ninguna
# La letra 'e' no está en la palabra
# Te quedan 5 intentos
# Letras incorrectas: e
#
#      ------
#      |    |
#      |    O
#      |
#      |
#     _|_
#
# _ _ _ _ _ _ _ _ _ _ _ _ Turno de Jugador 2
# Letras usadas: e
