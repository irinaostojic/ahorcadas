# %%
import random        #librería que necesito para hacer las combinaciones aleatorias

palabras = ['lógica', 'proactividad', 'creatividad', 'resiliencia', 'comunicación']
palabra = random.choice(palabras)      # le digo a python que me saque una palabra aleatoria de mi lista
print(palabra)         #quiero ver la palabra qué es solo para ir viendo qué pasa y probando 

print("=== Juego del Ahorcado ===")    #mensaje de entrada para empezar el juego

ahorcado = [
    """
     +---+
     |   |
         |
         |
         |
         |
    =========
    """,
    """
     +---+
     |   |
     O   |
         |
         |
         |
    =========
    """,
    """
     +---+
     |   |
     O   |
     |   |
         |
         |
    =========
    """,
    """
     +---+
     |   |
     O   |
    /|   |
         |
         |
    =========
    """,
    """
     +---+
     |   |
     O   |
    /|\\  |
         |
         |
    =========
    """,
    """
     +---+
     |   |
     O   |
    /|\\  |
    /    |
         |
    =========
    """,
    """
     +---+
     |   |
     O   |
    /|\\  |
    / \\  |
         |
    =========
    """
]     # es una simple lista de dibujos con el ahorcado. Si queremos caritas tenemos que hacer tupla

intentos = len(ahorcado) - 1 # 7 dibujitos, 1 por defecto, se lo resto
contador_fallos = 0   # le ponemos un contador de intentos fallidos, como mucho tendremos 6

letras_usadas = set() # conjunto de las letras que vamos usando
letras_correctas = set() # conjunto de las letras que vamos acertando

# creo que es más correcto utilizar conjuntos, pues no necesitamos ningún orden
print(f"Tienes {intentos} intentos fallidos para adivinar la palabra.")
# Out:
# comunicación
# === Juego del Ahorcado ===
# Tienes 6 intentos fallidos para adivinar la palabra.

# %%
# Empezamos con la lógica del juego

while True:
    print(ahorcado[fallos])

    palabra_mostrada = ""
    for letra in palabra:
        if letra.lower() in letras_correctas:
            palabra_mostrada += letra + " "
        else:
            palabra_mostrada += "_ "
    print("\nPalabra:", palabra_mostrada.strip())


    if letras_usadas:
        print("Letras que ya hemos probado:", " ".join(sorted(letras_probadas)))


    letras_unicas = set(letra.lower() for letra in palabra)
    if letras_unicas.issubset(letras_correctas):
        print(f"¡Enhorabuena! Has acertado la palabra: {palabra}")
        break   # salimos del bucle y terminamos el juego

    intento = input("\nIntroduce la letra que desees: ").lower().strip() #el jugador introduce la letra

    
    # hacemos validaciones. Por ejemplo
    
    if not intento.isalpha(): # no has introducido letras
        print("Solo puedes introducir letras.")
        continue 

    if len(intento) != 1: # le has puesto más de una letra sin darte cuenta
        print("Introduce solo una letra.")
        continue

    if intento in letras_usadas:
        print("Ya has probado esa letra.")
        continue

    letras_usadas.add(intento)

    if intento in palabra.lower():
        letras_correctas.add(intento)
        print("La letra es correcta")
    else:
        fallos += 1    # te va sumando al contador de fallos
        print("La Letra es incorrecta.")
        
        if fallos == intentos:    # has agotado todos los fallos
            print(ahorcado[fallos])
            print(f"¡GAME OVER! La palabra era: {palabra}")
            break
# Out:
#      +---+
#      |   |
#          |
#          |
#          |
#          |
# ...
#
#
# Palabra: _ _ _ _ _ _ _ _ _ _ _ _
# ❌ Solo puedes introducir letras.
#
#      +---+
#      |   |
#          |
#          |
#          |
#          |
# ...
#
#
# Palabra: _ _ _ _ _ _ _ _ _ _ _ _
# ❌ Solo puedes introducir letras.
#
#      +---+
#      |   |
#          |
#          |
#          |
#          |
# ...
#
#
# Palabra: _ _ _ _ _ _ _ _ _ _ _ _
# ❌ Solo puedes introducir letras.
#
#      +---+
#      |   |
#          |
#          |
#          |
#          |
# ...
#
#
# Palabra: _ _ _ _ _ _ _ _ _ _ _ _
# ❌ Solo puedes introducir letras.
#
#      +---+
#      |   |
#          |
#          |
#          |
#          |
# ...
#
#
# Palabra: _ _ _ _ _ _ _ _ _ _ _ _
# ❌ Solo puedes introducir letras.
#
#      +---+
#      |   |
#          |
#          |
#          |
#          |
# ...
#
#
# Palabra: _ _ _ _ _ _ _ _ _ _ _ _
# ❌ Solo puedes introducir letras.
#
#      +---+
#      |   |
#          |
#          |
#          |
# ...

# %%
# Cada vez que entras al while True, se muestra el dibujo actual
#  y el estado parcial de la palabra.

# El jugador introduce una letra que se valida
#  (solo una letra, no repetida, y que sea alfabética).

# Si la letra está en la palabra, se guarda en letras_correctas.

# #Si no, se incrementa el contador de fallos y se actualiza el dibujo.

# Cuando se adivinan todas las letras, el programa felicita y termina.

# Si se agotan los intentos, muestra que el jugador perdió y termina.
