# %%
import random

# --- Mazo: Arcanos Mayores (22) con significados ---
MEANINGS = {
    "El Mago": (
        "Tienes el poder de transformar tus ideas en algo real. No subestimes tu capacidad de empezar de nuevo.",
        "Alguien podría intentar seducirte con promesas que no son del todo claras."
    ),
    "La Sacerdotisa": (
        "Tu intuición es tu mejor aliada ahora. Escucha esa voz interior que rara vez se equivoca.",
        "El silencio puede esconder verdades que aún no quieres ver."
    ),
    "La Emperatriz": (
        "Es tiempo de dar vida a tus proyectos, de nutrir lo que amas y dejar que florezca.",
        "Si das demasiado sin medida, puedes sentirte vacía al final."
    ),
    "El Emperador": (
        "El orden y la disciplina pueden darte la estabilidad que buscas. Es un buen momento para organizarte.",
        "Aferrarte demasiado al control puede endurecer tu corazón."
    ),
    "El Hierofante": (
        "Busca la guía en lo aprendido, en la tradición o en alguien que respete tu camino. Hay sabiduría en lo compartido.",
        "Aferrarte ciegamente a lo establecido puede hacerte perder tu autenticidad."
    ),
    "Los Enamorados": (
        "Es un momento de decisiones importantes: escucha a tu corazón y actúa con honestidad contigo mismo.",
        "La indecisión puede hacerte perder lo que más valoras."
    ),
    "El Carro": (
        "La fuerza de tu voluntad te abre caminos. Avanza con confianza y claridad hacia donde quieres ir.",
        "El exceso de prisa puede hacerte perder el rumbo."
    ),
    "La Justicia": (
        "Hoy es un día para ser justo, contigo y con los demás. Actuar con equilibrio traerá claridad.",
        "Mirar solo desde un ángulo puede nublar tu juicio."
    ),
    "El Ermitaño": (
        "La respuesta que buscas está en tu interior. El silencio y la reflexión te mostrarán lo que necesitas.",
        "El aislamiento prolongado puede volverse una carga."
    ),
    "La Rueda de la Fortuna": (
        "La vida se mueve en ciclos: lo que baja vuelve a subir. Abraza el cambio como parte del viaje.",
        "Negarte a soltar lo que ya cumplió su tiempo te puede frenar."
    ),
    "La Fuerza": (
        "Tu paciencia y tu calma son más poderosas que la imposición. Dominas con ternura, no con fuerza bruta.",
        "Si te dejas llevar por el impulso, puedes perder lo que construiste."
    ),
    "El Colgado": (
        "Cambiar la mirada puede darte una respuesta inesperada. A veces soltar es el mayor acto de confianza.",
        "Quedarte inmóvil por miedo puede robarte oportunidades."
    ),
    "La Muerte": (
        "Un ciclo llega a su fin y con él nace una nueva posibilidad. Es el inicio disfrazado de final.",
        "Apegarte a lo viejo puede impedir que lo nuevo florezca."
    ),
    "La Templanza": (
        "Encuentras equilibrio al unir lo diferente. La armonía llega cuando no fuerzas el ritmo.",
        "El exceso de un lado u otro puede romper esa calma."
    ),
    "El Diablo": (
        "Reconocer tus deseos te ayuda a ser libre. Lo oculto en la sombra también forma parte de ti.",
        "Si te dejas atrapar por la tentación, perderás claridad."
    ),
    "La Torre": (
        "Un cambio repentino puede liberarte de lo que estaba estancado. Tras el derrumbe llega aire nuevo.",
        "Resistirte a ver la verdad puede hacer el golpe más duro."
    ),
    "La Estrella": (
        "La esperanza vuelve a brillar. Cree en tu luz, porque guía más de lo que imaginas.",
        "La desconfianza puede apagar ese brillo interior."
    ),
    "La Luna": (
        "Tus sueños y tu intuición te muestran mensajes escondidos. Permítete sentir lo que emerge de lo profundo.",
        "La confusión puede engañar si no miras con calma."
    ),
    "El Sol": (
        "La claridad y la alegría están contigo. Celebra lo que eres y lo que has logrado.",
        "Un exceso de optimismo puede hacerte ignorar señales importantes."
    ),
    "El Juicio": (
        "Es momento de despertar y tomar una decisión valiente. Escucha el llamado de tu propia vida.",
        "Si retrasas demasiado, la oportunidad puede desvanecerse."
    ),
    "El Mundo": (
        "Cierras un ciclo con éxito. Es tiempo de celebrar y reconocer cuánto has crecido.",
        "El miedo a soltar lo vivido puede impedirte avanzar al siguiente nivel."
    ),
    "El Loco": (
        "Un nuevo viaje empieza. La aventura te invita a confiar y dar el primer paso sin miedo.",
        "La imprudencia puede llevarte a tropezar si no prestas atención."
    )
}

deck=list(MEANINGS.keys()) #convierto el diccionario meanings en una lista de claves y la guardo en una variable.

def tirada_tarot(card=3):
    """
    Características:
    - Muestra un mensaje de bienvenida con tono místico.
    - Selecciona al azar 3 cartas (pasado, presente y futuro).
    - A cada carta se le asocia un mensaje interpretativo.
    - Usa un diccionario de significados para dar contexto a las cartas.
    """

    print("""Hola! Bienvenid@ a tu momento místico del día
    Esta es tu oportunidad de conectar con el universo.
    Concéntrate en tu pasado, tu presente y tu futuro...
    Deja que las cartas te muestren aquello que necesitas tener en cuenta.\n""")

    while True:
            respuesta = input("¿Estás preparada? (si / no / no se): ").strip().lower()
            
            
            
            if respuesta == "no se" or respuesta == "no sé":
                print("De los cobardes no se ha escrito nada...\n\n")
                continue

            elif respuesta == "no":
                print("Veo que tienes que pensártelo mejor. Tranquila, la próxima vez será.\n\n")
                return

            elif respuesta == "si":
                print("¡¡¡Excelente!!! ¡Esa es mi chica!\n\n")
                break

            else:
                print("Respuesta inválida. Por favor, escribe: si / no / no se")

    print("\nPresta atención...")

    select_cards = random.sample(deck, 3)# random.sample barajea y saca las 3 cartas de golpe y nunca se repiten.
    print("Se han elegido 3 cartas al azar:") 
    for i, card in enumerate(select_cards, start=1):#i itera por cada una de las cartas de select_cards y devuelve su indice. 
        print(f"{i}. {card}") #Imprime 3 cartas con salto de pagina por defecto.
    print(f"La carta de tu pasado es: {select_cards[0]} ,\n{MEANINGS[select_cards[0]]}") #imprime la carta y su significado dandole el indice en el que quiero que salgan.
    print(f"La carta de tu presente es: {select_cards[1]} ,\n{MEANINGS[select_cards[1]]}") 
    print(f"La carta de tu futuro es: {select_cards[2]} ,\n{MEANINGS[select_cards[2]]}")

# %%
tirada_tarot()
# Out:
# Hola! Bienvenid@ a tu momento místico del día
#     Esta es tu oportunidad de conectar con el universo.
#     Concéntrate en tu pasado, tu presente y tu futuro...
#     Deja que las cartas te muestren aquello que necesitas tener en cuenta.
#
# Veo que tienes que pensártelo mejor. Tranquila, la próxima vez será.
